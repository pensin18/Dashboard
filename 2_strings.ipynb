# %% [markdown]
# <a href="https://colab.research.google.com/github/pensin18/Dashboard/blob/main/2_strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = 'james'
age = 30
sent1 = 'my name is '+name+' and my age is  ' + str(age)

print('my name is',name,'and my age is',age)
sent1
# Out:
# my name is james and my age is 30
# 'my name is james and my age is  30'

# %%
"hell's"
# Out:
# "hell's"

# %%
# \n new line \t tab space  four spaces occupy more space than tab space
print('hello\nworl\td')
'hello\nworl\td'
# Out:
# hello
# worl	d
# 'hello\nworl\td'

# %%
greeting = 'hello world'
# starts index at 0 and increases by 1 even space has index

# %%
greeting[4]
greeting[5]
print(len(greeting))
# Out:
# 11

# %%
word = 'abcsgkosvvajode'
i = int(len(word)/2)
print(len_word)
mid_word = word[i]
mid_word
# Out:
# 7
# 's'

# %%
word = 'python'
word[0:2]
# starting index 0 : and end index +1    slicing
# Out:
# 'py'

# %%
word1 = 'Good'
half1 = len(word1)//2
end1 = word1[half1:]
# floor divison instead of convert to integer
word2 = 'Evening'
half2 = len(word2)//2
end2 = word2[half2:]

print(end1,end2)
# Out:
# od ning

# %%
num = 378.593
# 593.378
s1 = str(num)
start = s1[:3]
end = s1[4:]
f = end + '.'+start
ans = float(f)
ans
# Out:
# '593.378'
